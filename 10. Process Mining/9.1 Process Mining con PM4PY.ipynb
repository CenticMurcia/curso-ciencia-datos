# %% [markdown]
# # IMPORTS

# %%
import os

from pm4py.algo.discovery.heuristics import factory as heuristics_miner
from pm4py.objects.log.importer.xes import factory as xes_importer
from pm4py.visualization.heuristics_net import factory as hn_vis_factory
from pm4py.visualization.petrinet import factory as petri_vis_factory

# %% [markdown]
# # LOAD LOG

# %%
##### DOWNLOAD DATASET. ONLY IN COLAB !!!
# !wget -P ./../data/ https://raw.githubusercontent.com/CenticMurcia/curso-ciencia-datos/master/data/03_repairExample.xes.gz

# %%
log = xes_importer.apply('./../data/03_repairExample.xes.gz')

# %% [markdown]
# # PROCESS DISCOVERY: HEURISTIC MINER

# %%
heu_net = heuristics_miner.apply_heu(log, parameters={"dependency_thresh": 0.99})
net, im, fm = heuristics_miner.apply(log, parameters={"dependency_thresh": 0.99})

# %% [markdown]
# # PROCESS DIAGRAM 1

# %%
gviz = hn_vis_factory.apply(heu_net, parameters={"format": "png"})

# %%
hn_vis_factory.view(gviz)

# %% [markdown]
# # PROCESS DIAGRAM 2

# %%
gviz2 = petri_vis_factory.apply(net, im, fm, parameters={"format": "png"})

# %%
petri_vis_factory.view(gviz2)
