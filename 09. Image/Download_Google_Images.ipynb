# %% [markdown]
# # Install packages

# %%
# !pip install google_images_download
# !pip install split-folders
# Out:
# Collecting google_images_download
#   Downloading https://files.pythonhosted.org/packages/18/ed/0319d30c48f3653802da8e6dcfefcea6370157d10d566ef6807cceb5ec4d/google_images_download-2.8.0.tar.gz
# Collecting selenium (from google_images_download)
#   Downloading https://files.pythonhosted.org/packages/80/d6/4294f0b4bce4de0abf13e17190289f9d0613b0a44e5dd6a7f5ca98459853/selenium-3.141.0-py2.py3-none-any.whl (904kB)
#      |████████████████████████████████| 911kB 4.2MB/s
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.6/dist-packages (from selenium->google_images_download) (1.24.3)
# Building wheels for collected packages: google-images-download
#   Building wheel for google-images-download (setup.py) ... done
#   Created wheel for google-images-download: filename=google_images_download-2.8.0-py2.py3-none-any.whl size=14550 sha256=0909064c9bcc19dfd6afa3194e55db38693c5292ee07d3f1459e0f6a56ba747f
#   Stored in directory: /root/.cache/pip/wheels/1f/28/ad/f56e7061e1d2a9a1affe2f9c649c2570cb9198dd24ede0bbab
# Successfully built google-images-download
# Installing collected packages: selenium, google-images-download
# Successfully installed google-images-download-2.8.0 selenium-3.141.0
# Collecting split-folders
#   Downloading https://files.pythonhosted.org/packages/20/67/29dda743e6d23ac1ea3d16704d8bbb48d65faf3f1b1eaf53153b3da56c56/split_folders-0.3.1-py3-none-any.whl
# Installing collected packages: split-folders
# Successfully installed split-folders-0.3.1

# %% [markdown]
# # Import packages

# %%
from google_images_download import google_images_download
import split_folders

# %% [markdown]
# # Download imgs from Google
#
# It generate something like this:
#
# - downloads/
#   - class1/
#     - img1.jpg
#     - img2.jpg
#     - ...
#   - class2/
#     - imgWhatever.jpg
#     - ...
#   - ...

# %%
classes   = "Rabbit,Racoon"   # Choose your clases to search in Google Images

response  = google_images_download.googleimagesdownload()
arguments = {"keywords":classes, "limit":100, "print_urls":False}
paths     = response.download(arguments)
# Out:
# Item no.: 1 --> Item name = Rabbit
# Evaluating...
# Starting Download...
# Invalid or missing image format. Skipping...
# Completed Image ====> 1.Oryctolagus_cuniculus_Rcdo.jpg
# Completed Image ====> 2.us-movie-rabbits-meaning.jpg
# Completed Image ====> 3.65xDQxBV26qkgupGHbJSSZ-320-80.jpg
# Invalid or missing image format. Skipping...
# Completed Image ====> 4.bunny-in-field.jpg
# Completed Image ====> 5.557234-istock-480927021.jpg
# Completed Image ====> 6.gettyimages-10141026_slide-67be9fc1bca330b26debade87690b5e84286614d-s800-c85.jpg
# Completed Image ====> 7.lead-rabbit-fwak6w.jpg
# Completed Image ====> 8.Oryctolagus_cuniculus_Tasmania_2.jpg
# Completed Image ====> 9.rabbits%20-%20company.jpg
# Completed Image ====> 10.d20375-2.jpg
# Completed Image ====> 11.rabbit%20-%20pair.jpg
# Completed Image ====> 12.european-rabbit.jpg
# Completed Image ====> 13.ebjj1g.jpg
# Completed Image ====> 14.rabbits-crazy-march-1a.jpg
# Completed Image ====> 15.98ad270cea94ecf33469da28db304f41.jpg
# Completed Image ====> 16.11434993_web1_180418-ISJ-Rabbits_2.jpg
# Completed Image ====> 17.rabbit-433737.jpg
# Completed Image ====> 18.qi_2540330c.jpg
# Completed Image ====> 19.Image-6k-Other-pets-section_white-and-brown-rabbit.jpg
# Completed Image ====> 20.nintchdbpict000212879086.jpg
# Completed Image ====> 21.lnc-rabbit-vet-care.jpg
# Completed Image ====> 22.rabbit-hutches-and-cages-main-image.jpg
# Completed Image ====> 23.MA_00932390_mqjlib.jpg
# Completed Image ====> 24.cute-2500929-1200x800.jpg
# Completed Image ====> 25.rabbits-235417.jpg
# URLError on an image...trying next one... Error: <urlopen error unknown url type: x-raw-image>
# Completed Image ====> 26.4915.jpg
# Completed Image ====> 27.rabbit-awareness-week-.jpg
# Completed Image ====> 28.maxresdefault.jpg
# Completed Image ====> 29.cute-rabbit.jpg
# Completed Image ====> 30.rabbit-arrow-e1563834292545.jpg
# Completed Image ====> 31.methode%2Ftimes%2Fprod%2Fweb%2Fbin%2Ffd88d450-fb0b-11e7-9a34-94e1b34681c3.jpg
# Completed Image ====> 32.rabbit-meat-250x250.jpg
# Completed Image ====> 33.destructive-rabbit-295542884.jpg
# Completed Image ====> 34.image.jpg
# Completed Image ====> 35._106494600_gettyimages-997540186-1.jpg
# Completed Image ====> 36.Rabbit.jpg
# Completed Image ====> 37.6c8248656-130712-frankenstein-rabbit-hmed-405p.nbcnews-ux-1024-900.jpg
# Completed Image ====> 38.RabbitsGeneric_large.jpg
# Completed Image ====> 39.image_180215-rabbit-thumb.jpg
# Completed Image ====> 40.4390.jpg
# Completed Image ====> 41.two-rabbits-playing.jpg
# Completed Image ====> 42.Adopt-a-rabbit-from-RSPCA.jpg
# Completed Image ====> 43.gary-bendig-169660-unsplash-668x336.jpg
# Completed Image ====> 44.Mead-Peter-Rabbit.jpg
# Completed Image ====> 45.bunny-1200x795.jpg
# Completed Image ====> 46.bad-rabbit-ransomware-attacks-highlight-risk-of-propagating-malware-outbreaks-630x330.jpg
# Completed Image ====> 47.Sylvilagus_floridanus_14136.JPG
# Completed Image ====> 48.RabbitEatingGrass.jpg
# Completed Image ====> 49.557234-istock-931209196.jpg
# Invalid or missing image format. Skipping...
# Completed Image ====> 50.healthy-rabbits.jpg
# Completed Image ====> 51.rabbit-.jpg
# Completed Image ====> 52.rabbit1.jpg
# Completed Image ====> 53.Rabbit-cute-2.jpg
# Completed Image ====> 54.10-reasons-rescue-rabbits-rule-thinkstock-148125620.jpg
# Completed Image ====> 55.71UnrWaTe6L._SX425_.jpg
# Completed Image ====> 56.lion_rabbit_web-1024x683.jpg
# Completed Image ====> 57.dutch-rabbit.jpg
# Completed Image ====> 58.the-eagle-the-rabbit-and-the-fox.jpg
# Completed Image ====> 59.small-animal-rabbit-in-tunnel.jpg
# Completed Image ====> 60.Sundar-rabbits-tho.jpg
# Completed Image ====> 61.rabbit-T2.jpg
# Invalid or missing image format. Skipping...
# Completed Image ====> 62.rabbit-1.jpg
# Completed Image ====> 63.image.webp
# Completed Image ====> 64.Rabbit_Temp_-_PIN._1_1024x1024.png
# Completed Image ====> 65.AFL.jpg
# Completed Image ====> 66.Rabbit-facts-featured.jpg
# Completed Image ====> 67.melissa-kite.jpg
# Completed Image ====> 68.rabbit_sound_305_seahill-56a4a9605f9b58b7d0d82213.jpg
# Completed Image ====> 69.rabbit-pixabay-rabbit-control-page.jpg
# Completed Image ====> 70.TELEMMGLPICT000165561076_1_trans_NvBQzQNjv4BqFArV4Au1G82JHSdskK1VWfr7sARQy7EgBjwPUzvqL_M.jpeg
jpg
# Invalid or missing image format. Skipping...
# Completed Image ====> 66.ete-ratonlaveur30.jpg
# Completed Image ====> 67.41%2Bf5CnX8uL._SR600%2C315_PIWhiteStrip%2CBottomLeft%2C0%2C35_PIAmznPrime%2CBottomLeft%2C0%2C-5_PIStarRatingFOURANDHALF%2CBottomLeft%2C360%2C-6_SR600%2C315_ZA(386%20Reviews)%2C445%2C291%2C400%2C400%2Carial%2C12%2C4%2C0%2C0%2C5_SCLZZZZZZZ_.jpg
# Completed Image ====> 68.PAPO_racoon-53016a_700_advice_from_a_caterpillar_toronto_childrens_store_toy_store_1024x1024.jpg
# Completed Image ====> 69.cortes-island-raccoon-photo-1496.jpg
# Completed Image ====> 70.canva-a-sweet-little-racoon-MADatnCxL7Q.jpg
# Completed Image ====> 71.Racoon-820x574.jpg
# Completed Image ====> 72.961fa07d-a993-4004-b593-8a12aca04a7d.jpg
# Completed Image ====> 73.racoon-1.png
# Completed Image ====> 74.5131622_021019-ewn-530-racoon-vid.jpg
# Completed Image ====> 75.racoon-dancing-white-background_1308-19143.jpg
# Completed Image ====> 76.Racoon.progressive.jpg
# Completed Image ====> 77.Ode-To-A-Dead-Raccoon-spillwords-1.jpg
# Completed Image ====> 78.iStock_000003450186Large_Adjust-500px.jpg
# Completed Image ====> 79.racoon.jpg
# Completed Image ====> 80.dabolical-racoon-prints.jpg
# Completed Image ====> 81.WildBoar-Racoon-600-fea.jpg
# Completed Image ====> 82.baby-racoon-5169185.jpg
# Completed Image ====> 83.il_794xN.1935639443_7aro.jpg
# Completed Image ====> 84.61Tn%2BIQL0yL._SX466_.jpg
# Completed Image ====> 85.ARGES_header_L_2000x624_racoon_2018.jpg
# Completed Image ====> 86.0bc8164dc972e018a93afd6bc82c850c.jpg
# Invalid or missing image format. Skipping...
# Invalid or missing image format. Skipping...
# Completed Image ====> 87.racoon-house-4.jpg
#
#
# Unfortunately all 100 could not be downloaded because some images were not downloadable. 87 is all we got for this search filter!
#
# Errors: 13

# %% [markdown]
# # Split imgs into train (90%) and valid (10%)
#
# It generate something like this:
#
# - dataset/
#   - train/
#     - class1/
#       - img1.jpg
#       - ...
#     - class2/
#       - imga.jpg
#       - ...
#   - val/
#     - class1/
#       - img2.jpg
#       - ...
#     - class2/
#       - imgb.jpg
#       - ...

# %%
split_folders.ratio('downloads', output="dataset", seed=0, ratio=(.9, .1))
# Out:
# Copying files: 179 files [00:00, 1430.84 files/s]

# %% [markdown]
# ### Rename val to valid (Fast.ai requirement)

# %%
# !mv dataset/val/ dataset/valid/

# %% [markdown]
# ### Remove downloads (not neccesary enymore)

# %%
# !rm -r downloads/

# %% [markdown]
# # Connect to Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# # Uplaod dataset to Google Drive

# %%
name              = "dataset_from_Google"                                     # Change the dataset name
drive_root_folder = "drive/My\\ Drive"
dataset_in_drive  = drive_root_folder + "/Notebooks/Datasets/" + name +"/"    # Change the datset location
print(dataset_in_drive)
# Out:
# drive/My\ Drive/Notebooks/Datasets/dataset_from_Google/

# %%
# !cp -r dataset $dataset_in_drive
