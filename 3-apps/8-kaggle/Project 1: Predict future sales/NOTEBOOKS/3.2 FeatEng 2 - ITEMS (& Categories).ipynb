# %% [markdown]
# <h3 align="center">Feature Engeneering 2</h3>
# <h1 align="center">ITEMS (& Cats)</h1>
#
# TODO: Save duplicated_items_replacement as JSON

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import category_encoders as ce
import json

pd.set_option('display.max_rows', 100)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ### Constants

# %%
ENGLISH = True

DATA_RUS_PATH = "../DATA/1. Original data Russian (96Mb)/"
DATA_ENG_PATH = "../DATA/2. Translated data English (1Mb)/"
DATA_FE_PATH  = "../DATA/3. Feature Engeneering/"
DATA_SUB_PATH = "../DATA/5. Submissions/"

# %% [markdown]
# ### Load data

# %%
sales = pd.read_csv(DATA_RUS_PATH + "sales_train.csv")          # Dayly sales  Jan 2013 -> Oct 2015
test  = pd.read_csv(DATA_RUS_PATH + "test.csv", index_col="ID") # Predict Noviember 2015
sub   = pd.read_csv(DATA_RUS_PATH + "sample_submission.csv", index_col="ID")

if ENGLISH: 
    shops = pd.read_csv(DATA_ENG_PATH + "shops.csv", index_col="shop_id") # 60
    items = pd.read_csv(DATA_ENG_PATH + "items.csv") # 22170
    cats  = pd.read_csv(DATA_ENG_PATH + "item_categories.csv", index_col="item_category_id") # 84

else:
    shops = pd.read_csv(DATA_RUS_PATH + "shops.csv", index_col="shop_id") # 60
    items = pd.read_csv(DATA_RUS_PATH + "items.csv") # 22170
    cats  = pd.read_csv(DATA_RUS_PATH + "item_categories.csv", index_col="item_category_id") # 84

# %% [markdown]
# # <center> Categories (84)

# %%
pd.DataFrame(cats.item_category_name.values.reshape(-1, 4))
# Out:
#                                           0  \
# 0                PC - Headsets / Headphones
# 1                         Accessories - PSP
# 2                         Tickets (Digital)
# 3                       Game consoles - PS4
# 4                  Game consoles - XBOX ONE
# 5                               Games - PS4
# 6                          Games - XBOX ONE
# 7            PC Games - Additional Editions
# 8      Payment Cards (Cinema, Music, Games)
# 9         Payment cards - Windows (Digital)
# 10                             Cinema - DVD
# 11               Books - Audiobooks (Digit)
# 12              Books - Computer literature
# 13                           Books - Guides
# 14       Music - CD of corporate production
# 15                    Music - Gift editions
# 16                      Gifts - Board games
# 17           Gifts - Certificates, services
# 18                          Gifts - Figures
# 19   Programs - For home and office (Digit)
# 20                        Service - Tickets
#
#                                        1                                  2  \
# 0                      Accessories - PS2                  Accessories - PS3
# 1                   Accessories - PSVita             Accessories - XBOX 360
# 2                      Delivery of goods                Game consoles - PS2
# 3                    Game consoles - PSP             Game consoles - PSVita
# 4                 Game consoles - Others                        Games - PS2
# 5                            Games - PSP                     Games - PSVita
# 6               Games - Game accessories             Android games - Number
# 7        PC Games - Collector's Editions       PC Games - Standard Editions
# 8                  Payment Cards - Live!    Payment Cards - Live! (Digital)
# 9                       Cinema - Blu-Ray                Cinema - Blu-Ray 3D
# 10                  Cinema - Collector's   Books - Artbooks, encyclopedias
# 11                 Books - Audiobooks 1C        Books - Business literature
# 12   Books - Methodological materials 1C                  Books - Postcards
# 13                       Books - Fiction                    Books - Digital
# 14                           Music - MP3                      Music - Vinyl
# 15                    Gifts - Attributes   Gifts - Gadgets, robots , sports
# 16         Gifts - Board games (compact)            Gifts - Cards, stickers
# 17                     Gifts - Souvenirs         Gifts - Souvenirs (hinged)
# 18           Programs - 1C: Enterprise 8             Programs - MAC (Digit)
# 19                Programs - Educational     Programs - Educational (Digit)
# 20                   Blank media (spire)               Blank media (piece)
#
#                                    3
# 0                  Accessories - PS4
# 1             Accessories - XBOX ONE
# 2                Game consoles - PS3
# 3           Game consoles - XBOX 360
# 4                        Games - PS3
# 5                   Games - XBOX 360
# 6                 MAC Games - Number
# 7                 PC Games - Digital
# 8                Payment cards - PSN
# 9                Cinema - Blu-Ray 4K
# 10                Books - Audiobooks
# 11             Books - Comics, manga
# 12      Books - Cognitive literature
# 13    Music - CD of local production
# 14               Music - Music video
# 15                 Gifts - Soft toys
# 16               Gifts - Development
# 17   Gifts - Bags, Albums, Mousepads
# 18    Programs - For home and office
# 19                           Service
# 20                         Batteries

# %% [markdown]
# ### Get Subcategories

# %%
pd.DataFrame({
    "c0": cats.item_category_name,
    "c1": cats.item_category_name.str.split('-').map(lambda x: x[0].strip()),
    "c2": cats.item_category_name.str.extract(r'(^[\w\s]*)')[0]
})
# Out:
#                                                        c0  \
# item_category_id
# 0                              PC - Headsets / Headphones
# 1                                       Accessories - PS2
# 2                                       Accessories - PS3
# 3                                       Accessories - PS4
# 4                                       Accessories - PSP
# 5                                    Accessories - PSVita
# 6                                  Accessories - XBOX 360
# 7                                  Accessories - XBOX ONE
# 8                                       Tickets (Digital)
# 9                                       Delivery of goods
# 10                                    Game consoles - PS2
# 11                                    Game consoles - PS3
# 12                                    Game consoles - PS4
# 13                                    Game consoles - PSP
# 14                                 Game consoles - PSVita
# 15                               Game consoles - XBOX 360
# 16                               Game consoles - XBOX ONE
# 17                                 Game consoles - Others
# 18                                            Games - PS2
# 19                                            Games - PS3
# 20                                            Games - PS4
# 21                                            Games - PSP
# 22                                         Games - PSVita
# 23                                       Games - XBOX 360
# 24                                       Games - XBOX ONE
# 25                               Games - Game accessories
# 26                                 Android games - Number
# 27                                     MAC Games - Number
# 28                         PC Games - Additional Editions
# 29                        PC Games - Collector's Editions
# 30                           PC Games - Standard Editions
# 31                                     PC Games - Digital
# 32                   Payment Cards (Cinema, Music, Games)
# 33                                  Payment Cards - Live!
# 34                        Payment Cards - Live! (Digital)
# 35                                    Payment cards - PSN
# 36                      Payment cards - Windows (Digital)
# 37                                       Cinema - Blu-Ray
# 38                                    Cinema - Blu-Ray 3D
# 39                                    Cinema - Blu-Ray 4K
# 40                                           Cinema - DVD
# 41                                   Cinema - Collector's
# 42                       Books - Artbooks, encyclopedias
# 43                                     Books - Audiobooks
# 44                             Books - Audiobooks (Digit)
# 45                                  Books - Audiobooks 1C
# 46                            Books - Business literature
# 47                                  Books - Comics, manga
# 48                            Books - Computer literature
# 49                    Books - Methodological materials 1C
# 50                                      Books - Postcards
# 51                           Books - Cognitive literature
# 52                                         Books - Guides
# 53                                        Books - Fiction
# 54                                        Books - Digital
# 55                         Music - CD of local production
# 56                     Music - CD of corporate production
# 57                                            Music - MP3
# 58                                          Music - Vinyl
# 59                                    Music - Music video
# 60                                  Music - Gift editions
# 61                                     Gifts - Attributes
# 62                       Gifts - Gadgets, robots , sports
# 63                                      Gifts - Soft toys
# 81                                 Blank media (spire)        Blank media
# 82                                 Blank media (piece)        Blank media
# 83                                           Batteries           Batteries

# %%
cats['main_category'] = cats['item_category_name'].str.extract(r'(^[\w\s]*)')
cats['main_category'] = cats['main_category'].str.strip()
cats
# Out:
#                                        item_category_name      main_category
# item_category_id
# 0                              PC - Headsets / Headphones                 PC
# 1                                       Accessories - PS2        Accessories
# 2                                       Accessories - PS3        Accessories
# 3                                       Accessories - PS4        Accessories
# 4                                       Accessories - PSP        Accessories
# 5                                    Accessories - PSVita        Accessories
# 6                                  Accessories - XBOX 360        Accessories
# 7                                  Accessories - XBOX ONE        Accessories
# 8                                       Tickets (Digital)            Tickets
# 9                                       Delivery of goods  Delivery of goods
# 10                                    Game consoles - PS2      Game consoles
# 11                                    Game consoles - PS3      Game consoles
# 12                                    Game consoles - PS4      Game consoles
# 13                                    Game consoles - PSP      Game consoles
# 14                                 Game consoles - PSVita      Game consoles
# 15                               Game consoles - XBOX 360      Game consoles
# 16                               Game consoles - XBOX ONE      Game consoles
# 17                                 Game consoles - Others      Game consoles
# 18                                            Games - PS2              Games
# 19                                            Games - PS3              Games
# 20                                            Games - PS4              Games
# 21                                            Games - PSP              Games
# 22                                         Games - PSVita              Games
# 23                                       Games - XBOX 360              Games
# 24                                       Games - XBOX ONE              Games
# 25                               Games - Game accessories              Games
# 26                                 Android games - Number      Android games
# 27                                     MAC Games - Number          MAC Games
# 28                         PC Games - Additional Editions           PC Games
# 29                        PC Games - Collector's Editions           PC Games
# 30                           PC Games - Standard Editions           PC Games
# 31                                     PC Games - Digital           PC Games
# 32                   Payment Cards (Cinema, Music, Games)      Payment Cards
# 33                                  Payment Cards - Live!      Payment Cards
# 34                        Payment Cards - Live! (Digital)      Payment Cards
# 35                                    Payment cards - PSN      Payment cards
# 36                      Payment cards - Windows (Digital)      Payment cards
# 37                                       Cinema - Blu-Ray             Cinema
# 38                                    Cinema - Blu-Ray 3D             Cinema
# 39                                    Cinema - Blu-Ray 4K             Cinema
# 40                                           Cinema - DVD             Cinema
# 41                                   Cinema - Collector's             Cinema
# 42                       Books - Artbooks, encyclopedias               Books
# 43                                     Books - Audiobooks              Books
# 44                             Books - Audiobooks (Digit)              Books
# 45                                  Books - Audiobooks 1C              Books
# 46                            Books - Business literature              Books
# 47                                  Books - Comics, manga              Books
# 48                            Books - Computer literature              Books
# 49                    Books - Methodological materials 1C              Books
# 50                                      Books - Postcards              Books
# 51                           Books - Cognitive literature              Books
# 52                                         Books - Guides              Books
# 53                                        Books - Fiction              Books
# 54                                        Books - Digital              Books
# 55                         Music - CD of local production              Music
# 56                     Music - CD of corporate production              Music
# 57                                            Music - MP3              Music
# 58                                          Music - Vinyl              Music
# 59                                    Music - Music video              Music
# 60                                  Music - Gift editions              Music
# 61                                     Gifts - Attributes              Gifts
# 62                       Gifts - Gadgets, robots , sports              Gifts
# 63                                      Gifts - Soft toys              Gifts
# 64                                    Gifts - Board games              Gifts
# 65                          Gifts - Board games (compact)              Gifts
# 66                                Gifts - Cards, stickers              Gifts
# 67                                    Gifts - Development              Gifts
# 68                         Gifts - Certificates, services              Gifts
# 69                                      Gifts - Souvenirs              Gifts
# 70                             Gifts - Souvenirs (hinged)              Gifts
# 71                        Gifts - Bags, Albums, Mousepads              Gifts
# 72                                        Gifts - Figures              Gifts
# 73                            Programs - 1C: Enterprise 8           Programs
# 74                                 Programs - MAC (Digit)           Programs
# 75                         Programs - For home and office           Programs
# 76                 Programs - For home and office (Digit)           Programs
# 77                                 Programs - Educational           Programs
# 78                         Programs - Educational (Digit)           Programs
# 79                                                Service            Service
# 80                                      Service - Tickets            Service
# 81                                    Blank media (spire)        Blank media
# 82                                   Blank media (piece)         Blank media
# 83                                              Batteries          Batteries

# %% [markdown]
# ### Encode

# %%
encoder = ce.OrdinalEncoder(cols=["main_category"])

cats  = encoder.fit_transform(cats)
del cats['item_category_name']

cats.head()
# Out:
# /home/javi/.local/lib/python3.9/site-packages/category_encoders/utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):
#                   main_category
# item_category_id
# 0                             1
# 1                             2
# 2                             2
# 3                             2
# 4                             2

# %% [markdown]
# # <center> Items (22170)

# %%
items.head()
# Out:
#    item_id  item_category_id  \
# 0        0                40
# 1        1                76
# 2        2                40
# 3        3                40
# 4        4                40
#
#                                                                item_name
# 0                                 !! IN THE POWER OF HAPPINESS (PLAST) D
# 1  ! ABBYY FineReader 12 Professional Edition Full [PC, Digital Version]
# 2                                  *** IN THE GLORY OF THE GLORY (UNV) D
# 3                                                 *** BLUE WAVE (Univ) D
# 4                                                      *** BOX (GLASS) D

# %% [markdown]
# ### Clean

# %%
items['item_name'] = items['item_name'].str.lower()
items['item_name'] = items['item_name'].str.replace('.', '')
for i in [r'[^\w\d\s\.]', r'\bthe\b', r'\bin\b', r'\bis\b',
          r'\bfor\b', r'\bof\b', r'\bon\b', r'\band\b',  
          r'\bto\b', r'\bwith\b' , r'\byo\b']:
    items['item_name'] = items['item_name'].str.replace(i, ' ')
items['item_name'] = items['item_name'].str.replace(r'\b.\b', ' ')

items.head()
# Out:
# <ipython-input-9-0b8bc6632c2f>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   items['item_name'] = items['item_name'].str.replace('.', '')
# <ipython-input-9-0b8bc6632c2f>:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   items['item_name'] = items['item_name'].str.replace(i, ' ')
# <ipython-input-9-0b8bc6632c2f>:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   items['item_name'] = items['item_name'].str.replace(r'\b.\b', ' ')
#    item_id  item_category_id  \
# 0        0                40
# 1        1                76
# 2        2                40
# 3        3                40
# 4        4                40
#
#                                                                item_name
# 0                                            power   happiness  plast
# 1    abbyy finereader 12 professional edition full  pc  digital version
# 2                                                glory     glory  unv
# 3                                                     blue wave  univ
# 4                                                          box  glass

# %% [markdown]
# ### Find duplicates

# %%
dupes = items[(items.duplicated(subset=['item_name','item_category_id'],keep=False))]
dupes['in_test'] = dupes.item_id.isin(test.item_id.unique())
dupes = dupes.groupby('item_name').agg({'item_id':["count",'first','last'],'in_test':['first','last']})
dupes.head(15)
# Out:
# <ipython-input-10-62244aea463d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dupes['in_test'] = dupes.item_id.isin(test.item_id.unique())
#                                               item_id              in_test  \
#                                                 count first   last   first
# item_name
#                                                     2    32  10725    True
#       all   ballads     80                          2  7507   7508    True
#       art   electro swing     digipack              2  7453   7454   False
#       best   lounge     4cd  digibook               2  7456   7457   False
#       instrumental hits best                        2  7516   7517   False
#       love vocal house     2cd  digipack            2  7368   7369   False
#     armada lounge     2cd  digipack                 2  7258   7259   False
#     best radio tracks     2cd  digipack             3  7272   7275   False
#     classic trance tracks     3cd  digibook         2  7296   7297   False
#     clubber   mood   ibiza     2cd  digipack        3  7306   7308   False
#     dance   floor hits     mp3 cd   jewel           3  7311   7313   False
#     dance top hits     4cd  digibook                5  7319   7323   False
#     deep breeze     2cd  digipack                   2  7325   7326   False
#     deep house  dreams     2cd  digipack            3  7329   7331   False
#     deep house  series     2cd  digipack            2  7335   7338   False
#
#
#                                                 last
# item_name
#                                                False
#       all   ballads     80                      True
#       art   electro swing     digipack         False
#       best   lounge     4cd  digibook          False
#       instrumental hits best                   False
#       love vocal house     2cd  digipack       False
#     armada lounge     2cd  digipack            False
#     best radio tracks     2cd  digipack        False
#     classic trance tracks     3cd  digibook    False
#     clubber   mood   ibiza     2cd  digipack    True
#     dance   floor hits     mp3 cd   jewel      False
#     dance top hits     4cd  digibook           False
#     deep breeze     2cd  digipack              False
#     deep house  dreams     2cd  digipack        True
#     deep house  series     2cd  digipack        True

# %% [markdown]
# ### Remove duplicated

# %%
# A) if both item id's are in the test set do nothing
dupes = dupes[(dupes[('in_test', 'first')]==False) | (dupes[('in_test', 'last')]==False)]

# B) if only the first id is in the test set assign this id to both
temp = dupes[dupes[('in_test', 'first')]==True]
keep_first = dict(zip(temp[('item_id', 'last')], temp[('item_id',  'first')]))

# C) if neither id or only the second id is in the test set, assign the second id to both
temp = dupes[dupes[('in_test', 'first')]==False]
keep_second = dict(zip(temp[('item_id', 'first')], temp[('item_id',  'last')]))
item_map = {**keep_first, **keep_second}

item_map
# Out:
# {10725: 32,
#  17045: 17042,
#  21012: 21010,
#  21088: 21086,
#  21115: 21113,
#  21125: 21123,
#  21138: 21136,
#  169: 168,
#  573: 571,
#  11200: 11199,
#  8358: 8357,
#  16948: 16946,
#  1853: 1829,
#  9744: 9740,
#  8857: 8855,
#  21598: 21597,
#  10946: 10945,
#  18946: 18945,
#  8526: 8524,
#  22038: 22035,
#  18618: 18617,
#  10373: 10372,
#  9802: 9767,
#  11689: 11688,
#  20100: 20099,
#  22112: 22111,
#  12379: 12378,
#  4194: 4178,
#  4195: 4179,
#  4221: 4217,
#  13028: 13027,
#  16628: 13804,
#  14104: 14103,
#  16550: 16549,
#  5354: 5353,
#  15597: 15595,
#  17018: 17017,
#  5947: 5945,
#  17922: 17921,
#  18413: 18411,
#  8248: 8247,
#  21070: 21069,
#  21209: 21207,
#  21909: 21906,
#  18834: 18831,
#  19054: 19053,
#  18725: 18724,
#  20020: 20019,
#  15708: 15698,
#  7453: 7454,
#  7456: 7457,
#  7516: 7517,
#  7368: 7369,
#  7258: 7259,
#  7272: 7275,
#  7296: 7297,
#  7306: 7308,
#  7311: 7313,
#  7319: 7323,
#  7325: 7326,
#  7329: 7331,
#  7335: 7338,
#  7333: 7334,
#  7341: 7342,
#  21239: 21240,
#  21242: 21243,
#  21245: 21246,
#  21248: 21250,
#  7352: 7353,
#  7357: 7358,
#  7364: 7366,
#  7385: 7386,
#  7388: 7390,
#  7391: 7393,
#  7396: 7398,
#  7403: 7405,
#  7419: 7420,
#  7426: 7427,
#  21294: 21296,
#  21907: 21910,
#  21908: 21911,
#  18819: 18821,
#  18816: 18820,
#  18986: 18987,
#  9841: 9842,
#  19069: 19070,
#  11650: 11651,
#  11658: 11659,
#  11656: 11657,
#  16632: 16633,
#  19465: 19475,
#  18544: 18546,
#  18718: 18719,
#  19579: 19581,
#  12183: 12184,
#  9246: 9254,
#  9244: 9252,
#  9245: 9253,
#  9247: 9255,
#  14480: 14481,
#  21260: 21261,
#  21262: 21263,
#  21267: 21268,
#  19734: 19735,
#  19728: 19731,
#  19713: 19715,
#  19716: 19720,
#  19781: 19782,
#  19784: 19788,
#  16654: 16656,
#  19872: 19873,
#  10754: 10755,
#  15700: 15709,
#  15660: 15673,
#  9561: 9562,
#  11101: 11103,
#  16752: 16753,
#  9764: 9765,
#  16771: 16772,
#  16779: 16780,
#  16777: 16778,
#  16775: 16776,
#  10281: 10282,
#  21279: 21280,
#  18531: 18532,
#  8758: 8759,
#  7706: 7710,
#  7699: 7701,
#  14633: 14635,
#  7716: 7717,
#  8075: 8077,
#  8076: 8078,
#  10117: 10118,
#  11809: 11810}

# %% [markdown]
# ### Save item map

# %%
json_filename = DATA_FE_PATH + 'duplicated_items_replacement.json'

json.dump(item_map, open(json_filename, 'w'), indent=4)

# %% [markdown]
# ### Extract first n characters of name

# %%
items['item_name_no_space'] = items['item_name'].str.replace(' ', '')
items['item_name_first4']   = [x[:4] for x in items['item_name_no_space']]
items['item_name_first6']   = [x[:6] for x in items['item_name_no_space']]
items['item_name_first11']  = [x[:11] for x in items['item_name_no_space']]
del items['item_name_no_space']

items.head()
# Out:
#    item_id  item_category_id  \
# 0        0                40
# 1        1                76
# 2        2                40
# 3        3                40
# 4        4                40
#
#                                                                item_name  \
# 0                                            power   happiness  plast
# 1    abbyy finereader 12 professional edition full  pc  digital version
# 2                                                glory     glory  unv
# 3                                                     blue wave  univ
# 4                                                          box  glass
#
#   item_name_first4 item_name_first6 item_name_first11
# 0             powe           powerh       powerhappin
# 1             abby           abbyyf       abbyyfinere
# 2             glor           gloryg       glorygloryu
# 3             blue           bluewa       bluewaveuni
# 4             boxg           boxgla          boxglass

# %% [markdown]
# ### Encode

# %%
encoder = ce.OrdinalEncoder(cols=["item_name_first4", "item_name_first6", "item_name_first11"])

items  = encoder.fit_transform(items)
del items['item_name']

items.head()
# Out:
# /home/javi/.local/lib/python3.9/site-packages/category_encoders/utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):
#    item_id  item_category_id  item_name_first4  item_name_first6  \
# 0        0                40                 1                 1
# 1        1                76                 2                 2
# 2        2                40                 3                 3
# 3        3                40                 4                 4
# 4        4                40                 5                 5
#
#    item_name_first11
# 0                  1
# 1                  2
# 2                  3
# 3                  4
# 4                  5

# %% [markdown]
# ### JOIN with cats

# %%
items = pd.merge(items, cats, on="item_category_id", how="left")
items.head()
# Out:
#    item_id  item_category_id  item_name_first4  item_name_first6  \
# 0        0                40                 1                 1
# 1        1                76                 2                 2
# 2        2                40                 3                 3
# 3        3                40                 4                 4
# 4        4                40                 5                 5
#
#    item_name_first11  main_category
# 0                  1             12
# 1                  2             16
# 2                  3             12
# 3                  4             12
# 4                  5             12

# %% [markdown]
# ### Save

# %%
items.to_csv(DATA_FE_PATH + "items.csv")
